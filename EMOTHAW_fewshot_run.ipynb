# %% [markdown]
# <a href="https://colab.research.google.com/github/19ankita/Recognizing-Emotions-from-Handwriting-and-Drawing-Using-Online-and-Offline-Data-Modalities/blob/main/EMOTHAW_fewshot_run.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !rm -rf Recognizing-Emotions-from-Handwriting-and-Drawing-Using-Online-and-Offline-Data-Modalities

# %%
# !git clone https://github.com/19ankita/Recognizing-Emotions-from-Handwriting-and-Drawing-Using-Online-and-Offline-Data-Modalities.git
# Out:
# Cloning into 'Recognizing-Emotions-from-Handwriting-and-Drawing-Using-Online-and-Offline-Data-Modalities'...
# remote: Enumerating objects: 1632, done.
# remote: Counting objects: 100% (142/142), done.
# remote: Compressing objects: 100% (101/101), done.
# remote: Total 1632 (delta 43), reused 130 (delta 39), pack-reused 1490 (from 1)
# Receiving objects: 100% (1632/1632), 44.55 MiB | 11.99 MiB/s, done.
# Resolving deltas: 100% (140/140), done.

# %%
# cd to repo
# %cd /content/Recognizing-Emotions-from-Handwriting-and-Drawing-Using-Online-and-Offline-Data-Modalities
# Out:
# /content/Recognizing-Emotions-from-Handwriting-and-Drawing-Using-Online-and-Offline-Data-Modalities

# %%
# add PYTHONPATH
import os
os.environ["PYTHONPATH"] = "/content/Recognizing-Emotions-from-Handwriting-and-Drawing-Using-Online-and-Offline-Data-Modalities/fewshot_run"

# %%
# !pip install tensorboard

# %%
# run training
# %cd /content/Recognizing-Emotions-from-Handwriting-and-Drawing-Using-Online-and-Offline-Data-Modalities/fewshot_run/protonet

#!python run_train.py --task pentagon --auto
# !python run_train.py --task pentagon --encoder resnet18 --augment
# Out:
# /content/Recognizing-Emotions-from-Handwriting-and-Drawing-Using-Online-and-Offline-Data-Modalities/fewshot_run/protonet
# 2025-11-25 10:05:03.135028: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764065103.154969    9209 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764065103.161380    9209 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1764065103.177396    9209 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...
