# %% [markdown]
# ## Removing the old repo

# %%
# !rm -rf /content/Recognizing-Emotions-from-Handwriting-and-Drawing-Using-Online-and-Offline-Data-Modalities

# %% [markdown]
# ##Clonging the Github repo

# %%
# !git clone https://github.com/19ankita/Recognizing-Emotions-from-Handwriting-and-Drawing-Using-Online-and-Offline-Data-Modalities.git

# %% [markdown]
# ## Setting the root

# %%
# %cd /content/Recognizing-Emotions-from-Handwriting-and-Drawing-Using-Online-and-Offline-Data-Modalities/transfer_learning_regression/

# %% [markdown]
# ## Setting the python path

# %%
# add PYTHONPATH
import os
os.environ["PYTHONPATH"] = "/content/Recognizing-Emotions-from-Handwriting-and-Drawing-Using-Online-and-Offline-Data-Modalities/transfer_learning"

# %% [markdown]
# ## Training

# %%
# %cd /content/Recognizing-Emotions-from-Handwriting-and-Drawing-Using-Online-and-Offline-Data-Modalities/transfer_learning_regression/
# !python run_train.py \
  --task words \
  --task_dir data/emothaw_tasks \
  --label_csv features/words_with_dass.csv \
  --epochs 30 \
  --batch_size 32 \
  --img_size 224 \
  --val_ratio 0.2 \
  --freeze_backbone

# %%
# !zip -r outputs.zip outputs/

from google.colab import files
files.download('outputs.zip')

# %%
# !rm -rf /content/Recognizing-Emotions-from-Handwriting-and-Drawing-Using-Online-and-Offline-Data-Modalities/transfer_learning_regression/outputs
