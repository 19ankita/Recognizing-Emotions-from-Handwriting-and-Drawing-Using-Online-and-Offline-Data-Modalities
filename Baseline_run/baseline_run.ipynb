# %% [markdown]
# ## Removing the old repo

# %%
# !rm -rf /content/Recognizing-Emotions-from-Handwriting-and-Drawing-Using-Online-and-Offline-Data-Modalities

# %% [markdown]
# ## Clonging the Github repo

# %%
# !git clone https://github.com/19ankita/Recognizing-Emotions-from-Handwriting-and-Drawing-Using-Online-and-Offline-Data-Modalities.git
# Out:
# Cloning into 'Recognizing-Emotions-from-Handwriting-and-Drawing-Using-Online-and-Offline-Data-Modalities'...
# remote: Enumerating objects: 2303, done.
# remote: Counting objects: 100% (89/89), done.
# remote: Compressing objects: 100% (60/60), done.
# remote: Total 2303 (delta 57), reused 55 (delta 28), pack-reused 2214 (from 1)
# Receiving objects: 100% (2303/2303), 286.97 MiB | 28.75 MiB/s, done.
# Resolving deltas: 100% (598/598), done.
# Updating files: 100% (5234/5234), done.

# %% [markdown]
# ## Setting the root

# %%
# %cd Recognizing-Emotions-from-Handwriting-and-Drawing-Using-Online-and-Offline-Data-Modalities
# Out:
# /content/Recognizing-Emotions-from-Handwriting-and-Drawing-Using-Online-and-Offline-Data-Modalities

# %% [markdown]
# ## Installing the dependencies

# %%
# !pip install -r Baseline_run/requirements.txt
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from -r Baseline_run/requirements.txt (line 1)) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from -r Baseline_run/requirements.txt (line 2)) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from -r Baseline_run/requirements.txt (line 3)) (1.16.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from -r Baseline_run/requirements.txt (line 4)) (1.6.1)
# Requirement already satisfied: shap in /usr/local/lib/python3.12/dist-packages (from -r Baseline_run/requirements.txt (line 5)) (0.50.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->-r Baseline_run/requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->-r Baseline_run/requirements.txt (line 2)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->-r Baseline_run/requirements.txt (line 2)) (2025.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->-r Baseline_run/requirements.txt (line 4)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->-r Baseline_run/requirements.txt (line 4)) (3.6.0)
# Requirement already satisfied: tqdm>=4.27.0 in /usr/local/lib/python3.12/dist-packages (from shap->-r Baseline_run/requirements.txt (line 5)) (4.67.1)
# Requirement already satisfied: packaging>20.9 in /usr/local/lib/python3.12/dist-packages (from shap->-r Baseline_run/requirements.txt (line 5)) (25.0)
# Requirement already satisfied: slicer==0.0.8 in /usr/local/lib/python3.12/dist-packages (from shap->-r Baseline_run/requirements.txt (line 5)) (0.0.8)
# Requirement already satisfied: numba>=0.54 in /usr/local/lib/python3.12/dist-packages (from shap->-r Baseline_run/requirements.txt (line 5)) (0.60.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.12/dist-packages (from shap->-r Baseline_run/requirements.txt (line 5)) (3.1.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from shap->-r Baseline_run/requirements.txt (line 5)) (4.15.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.54->shap->-r Baseline_run/requirements.txt (line 5)) (0.43.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->-r Baseline_run/requirements.txt (line 2)) (1.17.0)

# %% [markdown]
# ## Setting the python path

# %%
# add PYTHONPATH
import os
os.environ["PYTHONPATH"] = "/content/Recognizing-Emotions-from-Handwriting-and-Drawing-Using-Online-and-Offline-Data-Modalities/Baseline_run"

# %% [markdown]
# ## Training the mdoels

# %%
# !python Baseline_run/main.py --all-tasks --mode all --cv --search --shap

# %% [markdown]
# ## Downloading the files at once

# %%
# zip everything inside results/
# !zip -r results.zip results/

# %%
from google.colab import files
files.download('results.zip')
