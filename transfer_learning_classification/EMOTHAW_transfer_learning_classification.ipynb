# %% [markdown]
# ## Removing the old repo

# %%
# !rm -rf /content/Recognizing-Emotions-from-Handwriting-and-Drawing-Using-Online-and-Offline-Data-Modalities

# %% [markdown]
# ##Clonging the Github repo

# %%
# !git clone https://github.com/19ankita/Recognizing-Emotions-from-Handwriting-and-Drawing-Using-Online-and-Offline-Data-Modalities.git

# %% [markdown]
# ## Setting the root

# %%
# %cd /content/Recognizing-Emotions-from-Handwriting-and-Drawing-Using-Online-and-Offline-Data-Modalities/transfer_learning_classification

# %% [markdown]
# ## Installing the dependencies

# %%
# !pip install albumentations==1.3.0
# !pip install opencv-python

# %% [markdown]
# ## Training and evaluating the model

# %%
# !rm -rf /content/Recognizing-Emotions-from-Handwriting-and-Drawing-Using-Online-and-Offline-Data-Modalities/transfer_learning_classification/outputs

# %% [markdown]
# ## Depression

# %%
# %cd /content/Recognizing-Emotions-from-Handwriting-and-Drawing-Using-Online-and-Offline-Data-Modalities/transfer_learning_classification
# !python run_train.py \
  --task words \
  --state depression \
  --task_dir data/emothaw_tasks \
  --label_csv features/words_with_dass.csv \
  --epochs 20 \
  --batch_size 32 \
  --freeze_backbone

# %% [markdown]
#  ## Anxiety

# %%
# %cd /content/Recognizing-Emotions-from-Handwriting-and-Drawing-Using-Online-and-Offline-Data-Modalities/transfer_learning_classification
# !python run_train.py \
  --task words \
  --state anxiety \
  --task_dir data/emothaw_tasks \
  --label_csv features/words_with_dass.csv \
  --epochs 20 \
  --batch_size 32 \
  --freeze_backbone

# %% [markdown]
# ## Stress

# %%
# %cd /content/Recognizing-Emotions-from-Handwriting-and-Drawing-Using-Online-and-Offline-Data-Modalities/transfer_learning_classification
# !python run_train.py \
  --task words \
  --state stress \
  --task_dir data/emothaw_tasks \
  --label_csv features/words_with_dass.csv \
  --epochs 20 \
  --batch_size 32 \
  --freeze_backbone

# %%
# !zip -r outputs.zip outputs/

from google.colab import files
files.download('outputs.zip')

# %%
# !ls -R outputs
