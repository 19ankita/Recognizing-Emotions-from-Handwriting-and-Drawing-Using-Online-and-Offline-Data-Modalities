# %% [markdown]
# ## Removing the old repo

# %%
# !rm -rf /content/Recognizing-Emotions-from-Handwriting-and-Drawing-Using-Online-and-Offline-Data-Modalities

# %% [markdown]
# ##Clonging the Github repo

# %%
# !git clone https://github.com/19ankita/Recognizing-Emotions-from-Handwriting-and-Drawing-Using-Online-and-Offline-Data-Modalities.git
# Out:
# Cloning into 'Recognizing-Emotions-from-Handwriting-and-Drawing-Using-Online-and-Offline-Data-Modalities'...
# remote: Enumerating objects: 2119, done.
# remote: Counting objects: 100% (213/213), done.
# remote: Compressing objects: 100% (138/138), done.
# remote: Total 2119 (delta 141), reused 137 (delta 71), pack-reused 1906 (from 2)
# Receiving objects: 100% (2119/2119), 207.65 MiB | 12.92 MiB/s, done.
# Resolving deltas: 100% (447/447), done.
# Updating files: 100% (4578/4578), done.

# %% [markdown]
# ## Setting the root

# %%
# %cd /content/Recognizing-Emotions-from-Handwriting-and-Drawing-Using-Online-and-Offline-Data-Modalities/transfer_learning
# Out:
# /content/Recognizing-Emotions-from-Handwriting-and-Drawing-Using-Online-and-Offline-Data-Modalities/transfer_learning

# %% [markdown]
# ## Setting the python path

# %%
# add PYTHONPATH
import os
os.environ["PYTHONPATH"] = "/content/Recognizing-Emotions-from-Handwriting-and-Drawing-Using-Online-and-Offline-Data-Modalities/transfer_learning"

# %% [markdown]
# ## Installing the dependencies

# %%
# !pip install albumentations==1.3.0
# !pip install opencv-python

# %%
# !pip install grad-cam

# %% [markdown]
# ## For CLI

# %%
# !python run_train.py --task cursive_writing --model resnet18 --task_dir data/emothaw_tasks

# %% [markdown]
# ## With configurations

# %%
#!python /content/Recognizing-Emotions-from-Handwriting-and-Drawing-Using-Online-and-Offline-Data-Modalities/transfer_learning/run_train.py --config configs/default.yaml

# %% [markdown]
# ## For training and validation plots

# %%
#!python /content/Recognizing-Emotions-from-Handwriting-and-Drawing-Using-Online-and-Offline-Data-Modalities/transfer_learning/utils/plot_training.py --history outputs/history.json

# %% [markdown]
# ## For confusion matrix and other plots

# %%
#%cd /content/Recognizing-Emotions-from-Handwriting-and-Drawing-Using-Online-and-Offline-Data-Modalities
#!python -m transfer_learning.utils.plot_all --history transfer_learning/outputs/history.json --model transfer_learning/outputs/best_model_cdt_resnet18.pth --task_dir transfer_learning/data/emothaw_tasks --task cdt

# %% [markdown]
# ## For augmentation visualizations

# %%
#%cd /content/Recognizing-Emotions-from-Handwriting-and-Drawing-Using-Online-and-Offline-Data-Modalities
#!python transfer_learning/utils/visualize_aug.py --task cdt --task_dir transfer_learning/data/emothaw_tasks --img_size 224

# %% [markdown]
# ## For pseudodynamic features visualizations

# %%
# %cd /content/Recognizing-Emotions-from-Handwriting-and-Drawing-Using-Online-and-Offline-Data-Modalities
# !python transfer_learning/utils/visualize_pseudodynamic_features.py \
  --image transfer_learning/data/emothaw_tasks/cdt/depression/u00017s00001_hw00006.png \
  --data_dir transfer_learning/data/emothaw_tasks/cdt \
  --save_dir transfer_learning/outputs
# Out:
# /content/Recognizing-Emotions-from-Handwriting-and-Drawing-Using-Online-and-Offline-Data-Modalities
# /content/Recognizing-Emotions-from-Handwriting-and-Drawing-Using-Online-and-Offline-Data-Modalities/transfer_learning/utils/visualize_pseudodynamic_features.py:120: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data, labels=class_names)
# /content/Recognizing-Emotions-from-Handwriting-and-Drawing-Using-Online-and-Offline-Data-Modalities/transfer_learning/utils/visualize_pseudodynamic_features.py:120: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data, labels=class_names)
# ...
